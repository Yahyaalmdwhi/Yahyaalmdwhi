# %% [markdown]
# #### Pyspark Basic Introduction

# %% [markdown]
# !pip install pyspark

# %%
# %pip install -U pip
# %pip install pandas pyarrow
# 1) تثبيت PySpark في نفس الكيرنل (مرة واحدة فقط)
# %pip install pyspark

# 2) الاستيراد
from pyspark.sql import SparkSession

# 3) إنشاء الـ SparkSession
spark = SparkSession.builder.appName("Practise").getOrCreate()

# 4) فحص سريع
print("Spark", spark.version, "| Master:", spark.sparkContext.master)
spark.range(10).count()




import pandas as pd
df = pd.read_csv('fx_rates_sample.csv')
df.info()
df.head()
type(df)
# Out:
# Requirement already satisfied: pip in c:\users\pc\desktop\neee\.venv\lib\site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002459A2E82D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002459A3B4790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002459A3B4FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002459A3B6010>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002459A3B6C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# Requirement already satisfied: pandas in c:\users\pc\desktop\neee\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: pyarrow in c:\users\pc\desktop\neee\.venv\lib\site-packages (21.0.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyspark in c:\users\pc\desktop\neee\.venv\lib\site-packages (4.0.1)
# Requirement already satisfied: py4j==0.10.9.9 in c:\users\pc\desktop\neee\.venv\lib\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.
# Spark 4.0.0 | Master: local[*]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  360 non-null    object
#  1   base       360 non-null    object
#  2   USD        360 non-null    float64
#  3   SAR        360 non-null    float64
#  4   YER        360 non-null    float64
#  5   EUR        360 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 17.0+ KB
# pandas.core.frame.DataFrame

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# ![1.png](attachment:image.png)

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://kubernetes.docker.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <img src="2.png" alt="Image 2"/>
# <img src="3.png" alt="Image 3"/>

# %% [markdown]
# ![Image 4](4.png)

# %% [markdown]
# ![image 5](5.png)

# %% [markdown]
# ![image 6](6.png)
